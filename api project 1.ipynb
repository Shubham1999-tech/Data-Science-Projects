# %% [markdown]
# # Project Description

# %%
from IPython.display import Image
Image("Pictures\zomayto.JPG")

# %%
import requests
import json

# %% [markdown]
# # question 1.1
#
# Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API.
# Print the cuisine_id.

# %%
h={"Accept":"application/json", "user-key":"1caff055a422302f378c3268226af592"}
r=requests.get("https://developers.zomato.com/api/v2.1/cuisines?city_id=1",headers=h)
x=r.json()
for i in x["cuisines"]:
    y=i['cuisine']
    if y['cuisine_name']=="Mexican":
        print(y["cuisine_id"])
# Out:
# 73

# %% [markdown]
# # question 1.3
#
# Fetch the entityid and entitytype of place Connaught Place.
# Print the entityid and entitytype,

# %%
r1=requests.get("https://developers.zomato.com/api/v2.1/locations?query=Connaught%20Place",headers=h)
x1=r1.json()
for i in x1['location_suggestions']:
    print(i['entity_type'],i["entity_id"])
# Out:
# subzone 104

# %% [markdown]
# #  question 1.4
#
# Fetch the top 10 best-rated restaurant serving ‘Mexican’ cuisine present in Connaught Place.
# Print the restaurant name, user rating and restaurant id.

# %%
r2=requests.get("https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&count=10&cuisines=73&sort=rating&order=desc",headers=h)
x2=r2.json()
for i in x2['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'])
####now we ll do questions by use of params
# Out:
# Chili's Grill & Bar 4.6 18537536
# 38 Barracks 4.6 18241537
# Ministry Of Beer 4.5 18418277
# Xero Degrees 4.4 18729557
# Farzi Cafe 4.3 18233593
# Bunta Bar Live 4.3 18623406
# Unplugged Courtyard 4.2 18216901
# Excuse Me Boss 4.2 307036
# Punjabi By Nature 4.2 306497
# The Art House Bar n Cafe 4.2 18863766

# %% [markdown]
# # question 1.5
#
# Fetch the category id of category type ‘Cafes’ using Zomato API.
# Print the category_id.

# %%
r3=requests.get('https://developers.zomato.com/api/v2.1/categories',headers=h)
x3=r3.json()
for i in range(len(x3['categories'])):
    j=x3['categories'][i]['categories']
    if j['name']=="Cafes":
        print(j['id'])
# Out:
# 6

# %% [markdown]
# #  question 1.6
#
# Fetch the best-rated restaurant for ‘Mexican’ cuisine with category type ‘ Cafes’ present in Connaught Place using Zomato API.
# Print the restaurant name, user rating and restaurant id.

# %%
r4=requests.get("https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&count=23&lat=28.632832&lon=77.219688&cuisines=73&category=6&sort=rating&order=desc"
,headers=h)
x4=r4.json()
print(r4.status_code)
for i in x4['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'])
    
    
#### doubt
# Out:
# 200
# Xero Degrees 4.4 18729557
# The Art House Bar n Cafe 4.2 18863766
# Cafe Delhi Heights 4.1 18579363
# Cafe Coffee Day - The Square 3.8 303034

# %%
p={}

# %% [markdown]
# # QUESTION 1.7
#
# Fetch the latest review of the best-rated restaurant for ‘Mexican’ cuisine with Category type ‘Cafes’ present in Connaught Place using Zomato API.
# Print the name of user ,user rating and review text.
# Note :
# Due to limitation of basic API plan it, can only fetch 5 latest review

# %%
r5=requests.get("https://developers.zomato.com/api/v2.1/reviews?res_id=18241537&count=5",headers=h)
h5=r5.json()
for i in range(len(h5["user_reviews"])):
    j=h5["user_reviews"][i]
    print(j['review']['user']['name'],j['review']['rating'],j['review']['review_text'])
#### output changes in accordance with reviews
# Out:
# Oye Pumpkin 5
# Sangeeta Sharma 5 Their live music , proper seating arrangement and the ambiance is too good.  I try their white sauce pasta  and chocolate shake Both are good in quantity and quality..
# Sahil Khan 5
# Deepak Phore 4 I love the ambience of this place. This place is beautiful and nice decorated ambience with a very good staff. Food is really amazing I just love the food at here. I tried paneer tikka and chilli paneer. Must visit here.   Food         4/5 Service     4.5/5 Ambience 5/5
# Anupriya Bhardwaj 3

# %% [markdown]
# #  QUESTION 2 BEGINNING

# %% [markdown]
# #  Question 2.2
#
# Fetch the details of "Pa Pa Ya" restaurant using Zomato API.
# Print the user rating, the average cost for two, cuisines and address of "Pa Pa Ya" restaurant.

# %%
re=requests.get("https://developers.zomato.com/api/v2.1/restaurant?res_id=18241524",headers=h)
he=re.json()
print(he['user_rating']['aggregate_rating'])
print(he['average_cost_for_two'])    
print(he['cuisines'])   
print(he['location']['address'])
# Out:
# 4.3
# 1400
# North Indian, Continental, Italian, Chinese
# G-15/B, Vijay Nagar, New Delhi

# %% [markdown]
# #  Question 2.3
#
# Find out whether online table reservation is supported in "Pa Pa Ya" restaurant or not using Zomato API.
# Print 'yes' if online table reservation is supported else 'no'
# Note :
# In Zomato response JSON. 1=Yes and 0 = No

# %%
if (he['is_table_reservation_supported'])==1:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# #  Question 2.4
#
# Fetch the latest review of "Pa Pa Ya" restaurant using Zomato API.
# Print the name of the user, user rating and review text.
# Note :
# Due to the limitation of the basic API plan, it can only fetch 5 latest review

# %%
re1=requests.get("https://developers.zomato.com/api/v2.1/reviews?res_id=18241524&count=5",headers=h)
he1=re1.json()
for i in range(len(he1['user_reviews'])):
    j=he1['user_reviews'][i]['review']
    print(j['user']['name'],j['rating'],j['review_text'])
# Out:
# Palak Sharma 4
# Ankita Sharma | Geographyedible 😎✌️ 5 All time favourite place ♥️💝
# Lavanya Kv 4
# Foodieszonee 4 It’s a very nice place to hangout and has a very nice ambience, great dj and the food was very good must try white sauce pasta.  Good and fast service also reasonable price.
# Prerana Verma 5

# %% [markdown]
# #  Question 3

# %% [markdown]
# # 3.1
#
# Fetch the cuisine_id of of cuisine ‘BBQ’ using Zomato API.
# Print the cuisine_id

# %%
re2=requests.get("https://developers.zomato.com/api/v2.1/cuisines?city_id=1&lat=28.6975&lon=77.140",headers=h)
he2=re2.json()
for i in range(len(he2['cuisines'])):
    if he2['cuisines'][i]['cuisine']['cuisine_name']=="BBQ":
        print(he2['cuisines'][i]['cuisine']['cuisine_id'])
# Out:
# 193

# %% [markdown]
# #  3.2
#
# Fetch the list of the top 10 restaurants serving cuisine ‘BBQ’ which are nearest to Coding Ninjas.
# Print the restaurant name, user rating, restaurant id and locality in which restaurant is present.

# %%
re3=requests.get("https://developers.zomato.com/api/v2.1/search?entity_type=subzone&count=10&lat=28.6895&lon=77.140&cuisines=193&sort=real_distance",headers=h)
he3=re3.json()
for i in he3['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])
# Out:
# Themis Barbecue House 4.5 18204820 Netaji Subhash Place
# Barbeque Nation 4.1 9561 Netaji Subhash Place
# UBQ by Barbeque Nation 3.7 19082741 Lawrence Road
# Moet's Barbeque 0 19238917 Alipur
# New Bombay Bar-Be-Que 3.6 5303 Prashant Vihar
# Amazings Kitchen 0 19370424 Prashant Vihar
# Kays Bar-Be-Que 3.8 3079 Ashok Vihar Phase 1
# UBQ by Barbeque Nation 3.8 18889760 Rohini
# 7teen BBQ Bistro Bnq 3.8 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar

# %%
he3
# Out:
# {'results_found': 118,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18204820},
#     'apikey': '1caff055a422302f378c3268226af592',
#     'id': '18204820',
#     'name': 'Themis Barbecue House',
#     'url': 'https://www.zomato.com/ncr/themis-barbecue-house-netaji-subhash-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Shop 251, 2nd Floor, Near Stanmax Aggarwal Millennium Tower 1, Netaji Subhash Place, New Delhi',
#      'locality': 'Netaji Subhash Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6939101917',
#      'longitude': '77.1492858231',
#      'zipcode': '110035',
#      'country_id': 1,
#      'locality_verbose': 'Netaji Subhash Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Mughlai, Desserts, Beverages',
# ...

# %% [markdown]
# # 3.3
#
# Fetch the latest review of the restaurant serving cuisine ‘BBQ’ which is most nearest to Coding ninjas?
# Print the name of user ,user rating and review text.
# Note :
# Due to limitation of basic API plan it, can only fetch 5 latest review

# %%
r4=requests.get("https://developers.zomato.com/api/v2.1/reviews?res_id=18204820&count=5",headers=h)
h4=r4.json()
for i in range(len(h4["user_reviews"])):
    j=h4["user_reviews"][i]
    print(j['review']['user']['name'],j['review']['rating'])
    print(j['review']['review_text'])
# Out:
# ANNANT VASHIST 5
# I celebrated my bday in Themis barbecue . I enjoyed a lot and the staff was really good nd the food is very delicious .
# Thatcravingfoodie 4
# ...

# %% [markdown]
# #  3.4
#
# Experiment with the radius parameter that is present in ‘GET/search’. Fetch the list of top 10 best-restaurant present in a radius of 4 km of coding ninjas.
# Print the restaurant name, user rating, restaurant id and locality in which restaurant is present.

# %%
r5=requests.get("https://developers.zomato.com/api/v2.1/search?entity_type=subzone&count=10&lat=28.6895&lon=77.140&radius=4000&sort=rating",headers=h)
he5=r5.json()
he5
for i in range(len(he5['restaurants'])):
    x = he5['restaurants'][i]['restaurant']
    print(x['name'], x['user_rating']['aggregate_rating'], x['id'], x['location']['locality'])
# Out:
# Ah So Yum 4.9 18945610 Golf Course Road
# Oishii Wok 4.9 19078918 DLF Phase 4
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Dana Choga 4.9 549 Sector 14
# Chili's Grill & Bar 4.9 18607069 Pacific Mall, Tagore Garden
# Son Of A Bun 4.9 19300210 Golf Course Road
# The Tandoori Tales 4.9 19231934 Sector 45
# Cafe Wink 4.8 7224 Anand Vihar
# Master Koii's 4.8 18819947 Sushant Lok
# Chili's Grill & Bar 4.8 4751 Ambience Mall, Vasant Kunj

# %% [markdown]
# # 3.5
#
# Compare the location of the restaurant whether really they are in a distance of 4 km to Coding Ninjas. Find out whether these API radius feature is working or not.
# Print 'yes' if radius feature work else print 'no'.
# Note :
# Use google search to find whether restaurant lie in range of 4km or not.

# %%
print("no ")
### our required location is coming in the gurgoan area where as our given location is in pitampura delji
# Out:
# no
